# %%
from qiskit import *
from qiskit.quantum_info import SparsePauliOp, Statevector

import numpy as np
import networkx as nx
from qiskit import QuantumRegister, QuantumCircuit
from qiskit.opflow import PauliSumOp
from qiskit.quantum_info import Pauli, SparsePauliOp

from math import cos, sin, cosh, sinh, atan, exp, pi
from scipy.optimize import minimize

import sys

import copy
import pickle

# from qubo_hamiltonian import *

import itertools
# Out:
# C:\Users\tuccia\AppData\Local\Temp\ipykernel_23020\126281046.py:7: DeprecationWarning: The ``qiskit.opflow`` module is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/opflow_migration.
#   from qiskit.opflow import PauliSumOp

# %% [markdown]
# Code from Yahui with adaptive lightcone

# %%
def partition_N(N:int):
    '''do the partition of a complete graph with N vertex, to find the optimal orders for edges to run circuit in parallel
    Args:
        N: number of qubits
    Return:
        pairs_all: list of qubit index pairs (edges) in a order to parallel the circuit
    '''
    indexs = range(N)
    pairs_all = []  

    ## swap indexes of even layer [0,1,2,3,4] -> [1,0,3,2,4]
    swap_even = [i + pow(-1, i) for i in range(N - (N%2))]  
    if (N%2) == 1:
        swap_even.append(N-1)
    ## swap indexes of even layer [0,1,2,3,4] -> [0,2,1,4,3]
    swap_odd = [0]
    swap_odd.extend([i + pow(-1, i+1) for i in range(1,N-(N+1)%2)])
    if (N%2) == 0:
        swap_odd.append(N-1)
    
    ## qubit pairs need to be implemented in layer 0
    pairs_even = [(i, i+1) for i in range(0, N-1, 2)]  
    pairs_all.append(pairs_even)
    indexs = np.array(indexs)[swap_even]   ### indexs after swap even

    for i in range(1, N):
        if (i%2)==1: ## odd layer
            pair_odd = [(indexs[i], indexs[i+1]) for i in range(1, N-1, 2)]
            pairs_all.append(pair_odd)
            indexs = np.array(indexs)[swap_odd]   ### indexs after swap odd

        elif (i%2)==0: ## even layer
            pair_even = [(indexs[i], indexs[i+1]) for i in range(0, N-1, 2)]
            pairs_all.append(pair_even)
            indexs = np.array(indexs)[swap_even]   ### indexs after swap even

    return pairs_all

def find_light_cone(edges_columns):
    """find the lightcone of all qubit pairs in previous one layer"""
    lightcone_dict = {}
    for index, pair_list in enumerate(edges_columns):
        for pair in pair_list:
            qi, qj = pair
            relevent_pairs = []  ##  qubit pairs in the previous layer that in the lightcone of the current pair
            if index > 0:
                for pair_layerm1 in edges_columns[index-1]: ## qubit pairs in the previous layer
                    if (qi in pair_layerm1) or (qj in pair_layerm1):
                        relevent_pairs.append(pair_layerm1)
            lightcone_dict[pair] = relevent_pairs
    return lightcone_dict

def find_light_cone2(edges_columns, pair_now, lnow, L):
    """find the pairs in lightcone including previous L layers for a specific qubit pair at layer lnow """
    lightcone = []
    qubit_list = list(pair_now) ## qubit index included, which is used to find the pair in lightcone in previous layer
    if L == 0:
        lightcone.append(pair_now)
    else:
        for index in range(lnow-1, max(0, lnow-L)-1, -1):
            pair_list = edges_columns[index]
            for pair in pair_list:
                if pair[0] in qubit_list or pair[1] in qubit_list:
                    lightcone.append(pair)
                    qubit_list.extend(pair)
        lightcone.append(pair_now)
    return lightcone

# %%
def ITE(N:int, edge_coeff_dict:dict, tau:float, eigen_list:np.array):
    
    eigens_ids = np.argsort(eigen_list)[:100]  ## return the id of the lowest 100 eigenvalues    ????
        
    edge_params_dict = {} ## to save the initial parameters for each vertex or edge in l'th layer
    exp_poss_dict = {}   ## save probalities of eigenvalues using warm start circuit

    q = QuantumRegister(N, name = 'q')
    circ = QuantumCircuit(q)
    circ.clear()
    circ.h(q[::])

    ## Z term 
    for i in range(N):
        #para = get_initial_para_1op_Y(N, [i], edge_coeff_dict[(i,)], tau, circ, shots, approximation)[0] #use this to extimate para from min expectation value
        tauc = tau * edge_coeff_dict[(i,)] 
        para = 2*atan( -exp(-2*tauc) ) + pi/2 #use this to use analytic formula (only valid for 1 layer)
        edge_params_dict[(i,)] = para
        circ.ry(para, i)
            
    ## ZZ term 
    state = Statevector(circ)
    for edge, coeff in edge_coeff_dict.items():
        if len(edge) == 2:
            tauc = tau * coeff
            state = circuit_update_zz(edge, state, tauc, N)

    state = np.array(state)
    for id in eigens_ids:
        eigen = eigen_list[id]
        poss = abs(state[id])**2
        # print('eigen', eigen, 'poss', poss)
        exp_poss_dict[eigen] = poss
    return exp_poss_dict, state

# %%
def circuit_update_zz(Edge,State, Tauc, N):
    '''update the state vector by applying exp(-tauc * ZZ) term to the current state vector'''
    i = min(Edge)
    j = max(Edge)

    zzop = SparsePauliOp.from_sparse_list([('ZZ', [j, i], -sinh(Tauc) )], N)
    zzop += SparsePauliOp.from_list([("I"*N, cosh(Tauc))])
    
    State = State.evolve(zzop)

    # Normalize the state vector manually
    norm = np.linalg.norm(State.data)
    State = State / norm

    # Print the normalized state vector
    # print("Normalized state:", State)

    return State

# %%
def circuit_update_theta(Edge, State, paras, N):
    
    j = min(Edge)    #I SWAPPED i AND j TO MATCH WITH YAHUI CIRCUIT
    i = max(Edge)

    zyop = SparsePauliOp.from_sparse_list([('ZY', [j, i], -1j*sin(paras[0]/2))], N)
    zyop += SparsePauliOp.from_list([("I"*N, cos(paras[0]/2))])

    yzop = SparsePauliOp.from_sparse_list([('YZ', [j, i], -1j*sin(paras[1]/2))], N)
    yzop += SparsePauliOp.from_list([("I"*N, cos(paras[1]/2))])

    op = zyop.compose(yzop)

    if len(paras) == 4:
        iyop = SparsePauliOp.from_sparse_list([('IY', [j, i], -1j*sin(paras[2]/2))], N)
        iyop += SparsePauliOp.from_list([("I"*N, cos(paras[2]/2))])
        op = op.compose(iyop)

        yiop = SparsePauliOp.from_sparse_list([('YI', [j, i], -1j*sin(paras[3]/2))], N)
        yiop += SparsePauliOp.from_list([("I"*N, cos(paras[3]/2))])
        op = op.compose(yiop)
    elif len(paras) == 6:
        xyop = SparsePauliOp.from_sparse_list([('XY', [j, i], -1j*sin(paras[4]/2))], N)
        xyop += SparsePauliOp.from_list([("I"*N, cos(paras[4]/2))])
        op = op.compose(xyop)

        yxop = SparsePauliOp.from_sparse_list([('YX', [j, i], -1j*sin(paras[5]/2))], N)
        yxop += SparsePauliOp.from_list([("I"*N, cos(paras[5]/2))])
        op = op.compose(yxop)
    
    State = State.evolve(op)

    # print('states2', State)

    return State

# %%
def square_modulus_cost_light_cone(Paras : list, *args):

    # para_init = np.zeros((len(lightcone_dict[edge]) + 1, 2))

    Edge_list = args[0]
    State = args[1]
    Tauc = args[2]
    Updated_state = args[3]
    N = args[4]

    State_zz = circuit_update_zz(Edge_list[-1], Updated_state, Tauc, N)
    
    if len(Paras) == 2*len(Edge_list):
        for index, edge in enumerate(Edge_list):
            Parameters = [Paras[2*index], Paras[2*index + 1]]
            State = circuit_update_theta(edge, State, Parameters, N)
    elif len(Paras) == 4*len(Edge_list):
        for index, edge in enumerate(Edge_list):
            Parameters = [Paras[4*index], Paras[4*index + 1], Paras[4*index + 2], Paras[4*index + 3]]
            State = circuit_update_theta(edge, State, Parameters, N)
    elif len(Paras) == 6*len(Edge_list):
        for index, edge in enumerate(Edge_list):
            Parameters = [Paras[6*index], Paras[6*index + 1], Paras[6*index + 2], Paras[6*index + 3], Paras[6*index + 4], Paras[6*index + 5]]
            State = circuit_update_theta(edge, State, Parameters, N)

    # Compute the scalar product (inner product) between the two state vectors
    inner_product = State_zz.inner(State)

    # Compute the square modulus of the inner product
    square_modulus = abs(inner_product)**2

    return - square_modulus

# %%
def warm_start_parameters_lightcone(N : int, tau:float, edge_coeff_dict : dict, edges_columns :list,  eigen_list:list, lightcone_dict: dict):    

    eigens_ids = np.argsort(eigen_list)[:100]  ## return the id of the lowest 100 eigenvalues    ????
    
    edge_params_dict = {} ## to save the initial parameters for each vertex or edge in l'th layer
    exp_poss_dict = {}   ## save probalities of eigenvalues using warm start circuit

    q = QuantumRegister(N, name = 'q')
    circ = QuantumCircuit(q)
    circ.clear()
    circ.h(q[::])

    # tau = 0.2

    # Z term
    for i in range(N):

        #para = get_initial_para_1op_Y(N, [i], edge_coeff_dict[(i,)], tau, circ, shots, approximation)[0] #use this to extimate para from min expectation value
        tauc = tau * edge_coeff_dict[(i,)] 
        para = 2*atan( -exp(-2*tauc) ) + pi/2 #use this to use analytic formula (only valid for 1 layer)
        edge_params_dict[(i,)] = para
        circ.ry(para, i)
        
    ## ZZ term 
    state = Statevector(circ)
    updated_state = state 

    #print('\nnumber of columns is:', len(edges_columns))

    for column_index, column in enumerate(edges_columns):
        # print('\n##################################################')
        # print('column index', column_index, 'column', column)

        if column_index == 0: 

            first_column_state = state

            for edge in column:
                
                if len(lightcone_dict[edge]) != 0:
                    sys.stderr.write('something is wrong with the lightcones')
                    sys.exit()
            
                # print('\nedge', edge)  

                tauc = tau * edge_coeff_dict[edge]

                para_init = [0,0]

                final = minimize(square_modulus_cost,
                                    para_init,
                                    args = (edge, first_column_state, tauc, N),
                                    jac=False,
                                    bounds=None,
                                    method='L-BFGS-B',
                                    callback=None,
                                    options={'maxiter': 1000})

                para = final.x

                # print('opt paramenters', para)
                # print('final square modulus', final.fun)

                edge_params_dict[edge] = para
                # print('edge_params_dict:', edge_params_dict)

                # print('old state', state)
                first_column_state = circuit_update_theta(edge, first_column_state, para, N)  #THIS LINE SHOULDN'T BE HERE BUT SOMEHOW THERE IS A TINY NUMERICAL ERROR IN THE THETAS IF I DON'T UPDATE THE CIRCUIT

                # print('first column state - new state', first_column_state)
            
        else:
            
            for edge in column: 
                if len(lightcone_dict[edge]) == 0:
                        sys.stderr.write('something is wrong with the lightcones')
                        sys.exit()

                # print('\nedge', edge)  

                # print('len light cone:', len(lightcone_dict[edge]), ', light cone edges:', lightcone_dict[edge])

                # print('initial state', state)

                updated_state = copy.deepcopy(state)
                
                for old_edge in lightcone_dict[edge]:
                    # print('old_edge', old_edge, 'param', edge_params_dict[old_edge])
                    updated_state = circuit_update_theta(old_edge, updated_state, edge_params_dict[old_edge], N)    
                
                # print('updated_state', updated_state)

                edge_list = lightcone_dict[edge] + [edge]
                # print('edge list', edge_list)
                
                tauc = tau * edge_coeff_dict[edge]

                para_init = np.zeros(2 + 2*len(lightcone_dict[edge]))
                # print('para init', para_init)

                final = minimize(square_modulus_cost_light_cone,
                        para_init,
                        args = (edge_list, state, tauc, updated_state, N),
                        jac=False,
                        bounds=None,
                        method='L-BFGS-B',
                        callback=None,
                        options={'maxiter': 1000})

                para = final.x
                # print('opt paramenters', para)
                # print('final square modulus', final.fun)

                para = (np.array(para)).reshape(-1, 2)
                # print('param list reshaped', para)
                for index, edge in enumerate(edge_list):
                    edge_params_dict[edge] = para[index] 
                # print('edge_params_dict', edge_params_dict)
            
            # print('\n######### previous column update ########')
            # print('column index', column_index, 'column', column)
            # print('previous column is:', edges_columns[column_index -1])

            for edge in edges_columns[column_index -1]:
                # print('edge', edge, 'parameter', edge_params_dict[edge])
                state = circuit_update_theta(edge, state, edge_params_dict[edge], N)

            # print('circuit updated ad the previous column i.e. column', column_index -1)
            # print('updated statevector', state)

    # print('\n######### last column update ########')
    # print('last column is:', edges_columns[ -1])

    for edge in edges_columns[ -1]:
        # print('edge', edge, 'parameter', edge_params_dict[edge])
        state = circuit_update_theta(edge, state, edge_params_dict[edge], N)

    # print('circuit updated at the last column i.e.', len(edges_columns) - 1)
    # print('updated statevector', state)

    #generate params_list
    values_as_arrays = [np.atleast_1d(value) for value in edge_params_dict.values()]
    # Concatenate and flatten all arrays into a single array
    flattened_array = np.concatenate(values_as_arrays)
    # Convert the flattened array to a list if needed
    params_list = flattened_array.tolist()
    # print(' params_list' , params_list )

    state = np.array(state)

    for id in eigens_ids:
        eigen = eigen_list[id]
        poss = abs(state[id])**2
        # print('eigen', eigen, 'poss', poss)
        exp_poss_dict[eigen] = poss

    return edge_params_dict, params_list, exp_poss_dict, state

# %%
def warm_start_parameters_old(N : int, tau:float, edge_coeff_dict : dict, edges_columns :list,  eigen_list:list):
    edge_params_dict = {} ## to save the initial parameters for each vertex or edge in l'th layer

    q = QuantumRegister(N, name = 'q')
    circ = QuantumCircuit(q)
    circ.clear()
    circ.h(q[::])


    # Z term
    for i in range(N):

        #para = get_initial_para_1op_Y(N, [i], edge_coeff_dict[(i,)], tau, circ, shots, approximation)[0] #use this to extimate para from min expectation value
        tauc = tau * edge_coeff_dict[(i,)] 
        para = 2*atan( -exp(-2*tauc) ) + pi/2 #use this to use analytic formula (only valid for 1 layer)

        edge_params_dict[(i,)] = para
        circ.ry(para, i)
        
    ## ZZ term 

    state = Statevector(circ)
    first_column_state = state

    for column_index, column in enumerate(edges_columns):
        for edge in column:
            tauc = tau * edge_coeff_dict[edge]
            para_init = [0.00,0.00]
            final = minimize(square_modulus_cost,
                                para_init,
                                args = (edge, first_column_state, tauc, N),
                                jac=False,
                                bounds=None,
                                method='L-BFGS-B',
                                callback=None,
                                options={'maxiter': 100})

            para = final.x

            # print('opt paramenters', para)
            # print('final square modulus', final.fun)

            edge_params_dict[edge] = para
            
            #print('old state', state)
            first_column_state = circuit_update_theta(edge, first_column_state, para, N)  #THIS LINE SHOULDN'T BE HERE BUT SOMEHOW THERE IS A TINY NUMERICAL ERROR IN THE THETAS IF I DON'T UPDATE THE CIRCUIT


    #generate params_list
    values_as_arrays = [np.atleast_1d(value) for value in edge_params_dict.values()]
    flattened_array = np.concatenate(values_as_arrays)
    params_list = flattened_array.tolist()

    state = np.array(first_column_state)
    eigens_ids = np.argsort(eigen_list)[:100]

    for id in eigens_ids:
        eigen = eigen_list[id]
        poss = abs(state[id])**2
        # print('eigen', eigen, 'poss', poss)
        exp_poss_dict[eigen] = poss
   
    return edge_params_dict, params_list, exp_poss_dict, state

# %%
def warm_start_parameters_adaptlightcone(N : int, tau:float, numpara:int, ampth:float, edge_coeff_dict : dict, edges_columns :list,  eigen_list:list, lightcone_dict: dict):
    '''' warm start the parameters for the circuit using the lightcone adaptivly
    Args:
        N: number of qubits
        tau: imaginary time
        numpara: number of parameters for each edge, 2, 4, or 6
        ampth: amplitude threshold, if the amplitude between optimized state and ITE state is larger than this value, the optimization stops; \
               otherwise continue with a larger lightcone including more previous layers
        edge_coeff_dict: coefficients for each edge
        edges_columns: list of edges in each layer
        eigen_list: list of eigenvalues
    Return:
        edge_params_dict: parameters for each edge
        params_list: list of parameters
        exp_poss_dict: probabilities of eigenvalues using warm start circuit
        state: final state vector 
    '''
    eigens_ids = np.argsort(eigen_list)[:100]  ## return the id of the lowest 100 eigenvalues    ????
    
    edge_params_dict = {} ## to save the initial parameters for each vertex or edge in l'th layer
    exp_poss_dict = {}   ## save probalities of eigenvalues using warm start circuit
    edge_coeff_dict_ite = {} ## record the edges has been executed, to get the ite state for each step

    q = QuantumRegister(N, name = 'q')
    circ = QuantumCircuit(q)
    circ.clear()
    circ.h(q[::])

    ## Z term 
    for i in range(N):
        tauc = tau * edge_coeff_dict[(i,)] 
        para = 2*atan( -exp(-2*tauc) ) + pi/2 #use this to use analytic formula (only valid for 1 layer)
        edge_params_dict[(i,)] = para
        circ.ry(para, i)

        edge_coeff_dict_ite[(i,)] = edge_coeff_dict[(i,)]
   
    
    ## ZZ term 
    state = Statevector(circ)
    for column_index, column in enumerate(edges_columns):
        print('\n### column index', column_index, 'column', column)
        if column_index == 0: 
            first_column_state = copy.deepcopy(state)
            for edge in column:
                if len(lightcone_dict[edge]) != 0:
                    sys.stderr.write('something is wrong with the lightcones')
                    sys.exit()
                edge_coeff_dict_ite[edge] = edge_coeff_dict[edge]
                _, state_ite = ITE(N, edge_coeff_dict_ite, tau, eigen_list)

                tauc = tau * edge_coeff_dict[edge]

                para_init = [0]* numpara
                final = minimize(square_modulus_cost_light_cone,
                        para_init,
                        args = ([edge], first_column_state, tauc, first_column_state, N),
                        jac=False,
                        bounds=None,
                        method='SLSQP',
                        callback=None,
                        options={'maxiter': 1000})
                para = final.x
                print('\nedge: ', edge,  ',  coeff: ', edge_coeff_dict[edge],  ',     final square modulus: ', final.fun)

                edge_params_dict[edge] = para

                #region check the overlap between the ite state and the optimized state
                state_opt = copy.deepcopy(state)
                for old_edge in edge_coeff_dict_ite.keys():
                    if len(old_edge) == 2:
                        state_opt = circuit_update_theta(old_edge, state_opt, edge_params_dict[old_edge], N)
                state_opt = np.array(state_opt)
                print('overlap between ite and optimized state: ', state_ite.T.conj() @ state_opt)
                
        else:
            for ei, edge in enumerate(column):  
                print('\nedge:', edge, ',  coeff:', edge_coeff_dict[edge])
                edge_coeff_dict_ite[edge] = edge_coeff_dict[edge]
                _, state_ite = ITE(N, edge_coeff_dict_ite, tau, eigen_list)
                ## optimize the gate in the lightcone including previous L layers
                for L in range(0, column_index+1):
                    lightcone = find_light_cone2(edges_columns, edge, column_index, L)  ## current edge is included in the lightcone, which is the last element in the list
                    print('~~L:', L, 'lightcone:', lightcone)

                    updated_state = copy.deepcopy(state)
                    optimized_state = copy.deepcopy(state)

                    para_init = []
                    edge_list = []  ## to save the edges in the lightcone that will be optimized
                    for ci in range(column_index-L):## previours layer before lightcone
                        for old_edge in edges_columns[ci]:
                            updated_state = circuit_update_theta(old_edge, updated_state, edge_params_dict[old_edge], N)  
                            optimized_state = circuit_update_theta(old_edge, optimized_state, edge_params_dict[old_edge], N)
                    for ci in range(column_index-L, column_index):## layer in lightcone      
                        for old_edge in edges_columns[ci]:
                            if old_edge in lightcone:
                                edge_list.append(old_edge)
                                para_init.extend(list(edge_params_dict[old_edge]))
                                updated_state = circuit_update_theta(old_edge, updated_state, edge_params_dict[old_edge], N) 
                    
                    tauc = tau * edge_coeff_dict[edge]

                    edge_list = edge_list + [edge]
                    para_init = para_init + [0]*numpara
                    #print('optimize edge list', edge_list, ',  para_init: ', para_init)
                    final = minimize(square_modulus_cost_light_cone,
                            para_init,
                            args = (edge_list, optimized_state, tauc, updated_state, N),
                            jac=False,
                            bounds=None,
                            method='SLSQP',
                            callback=None,
                            options={'maxiter': 1000})

                    para = final.x
                    print('final square modulus: ', final.fun)

                    ## check the overlap between the ite state and the optimized state
                    para = (np.array(para)).reshape(-1, numpara)
                    edge_para_dict = {edge:para[index] for index, edge in enumerate(edge_list)}
                    for ci in range(column_index-L, column_index+1):## layer in lightcone      
                        for old_edge in edges_columns[ci]:
                            if old_edge in edge_coeff_dict_ite.keys():
                                if old_edge in lightcone:
                                    optimized_state = circuit_update_theta(old_edge, optimized_state, edge_para_dict[old_edge], N)
                                else:
                                    optimized_state = circuit_update_theta(old_edge, optimized_state, edge_params_dict[old_edge], N)
                    optimized_state = np.array(optimized_state)
                    print('overlap between ite and optimized state: ', state_ite.T.conj() @ optimized_state)

                    if final.fun < -ampth:  ##
                        break

                ## update the parameters for the optimized edge
                for index, edge in enumerate(edge_list):
                    edge_params_dict[edge] = para[index]
                ## check the overlap between the ite state and the optimized state
                state_opt = copy.deepcopy(state)
                for old_edge in edge_coeff_dict_ite.keys():
                    if len(old_edge) == 2:
                        state_opt = circuit_update_theta(old_edge, state_opt, edge_params_dict[old_edge], N)
                state_opt = np.array(state_opt)
                print('overlap between ite and final optimized state: ', state_ite.T.conj() @ state_opt)
                 
                

    ## get the final state vector
    for ci in range(len(edges_columns)):
        for edge in edges_columns[ ci]:
            state = circuit_update_theta(edge, state, edge_params_dict[edge], N)

    #generate params_list
    values_as_arrays = [np.atleast_1d(value) for value in edge_params_dict.values()]
    # Concatenate and flatten all arrays into a single array
    flattened_array = np.concatenate(values_as_arrays)
    # Convert the flattened array to a list if needed
    params_list = flattened_array.tolist()
    # print(' params_list' , params_list )

    state = np.array(state)

    for id in eigens_ids:
        eigen = eigen_list[id]
        poss = abs(state[id])**2
        # print('eigen', eigen, 'poss', poss)
        exp_poss_dict[eigen] = poss
    return edge_params_dict, params_list, exp_poss_dict, state

# %%
def Hamiltonian_qubo(N, edge_list, h_list, J_list):
    """Hamiltonian defined by a N vertex graph with connected edge in edge_list
    Args:
        N: number of qubits
        edge_list: list of edges(qubit index pairs)
        h_list: coefficients of single Pauli Z term
        J_list: coefficients of ZZ term
    Return:
        H: PauliSumOp, Hamiltonian

    """
    pauli_list = []
    for i in range(N):
        pauli_str = (N-i-1)*'I' + 'Z' + i*'I'
        op = Pauli(pauli_str)
        pauli_list.append((op.to_label(), h_list[i]))
        
    for k, (i, j) in enumerate(edge_list):
        x_p = np.zeros(N, dtype = bool)
        z_p = np.zeros(N, dtype = bool)
        z_p[i] = True
        z_p[j] = True
        op = Pauli((z_p, x_p))
        pauli_list.append((op.to_label(), J_list[k]))
        
    H = PauliSumOp.from_list(pauli_list)
    
    return H

# %% [markdown]
# # Generate instances

# %%
N = 6
tau = 1
for r in range(10):
    print('\n\n#############################################################################')
    print('r:', r)
    #region load qubo instances, get Hamiltonian and edge_coeff_dict
    instance_dir = './instances/complete/N_' + str(N )
    with open(instance_dir + '/QUBO_' + str(N ) + 'V_comp_'+ '.gpickle', 'rb') as f:
        G = pickle.load(f)

    coeff_list = np.loadtxt(instance_dir + '/QUBO_coeff_' + str(N) + 'V_comp_'+ 'r_'+ str(r)+ '.txt')
    h_list = coeff_list[: N ]
    J_list = coeff_list[N :]

    edges_columns = partition_N(N)
    lightcone_dict = find_light_cone(edges_columns)
    edge_list = G.edges()
    pairs_all = list(itertools.chain.from_iterable(partition_N(N)))

    #extrcact Hamiltonian, edge coefficients and eigen list
    H = Hamiltonian_qubo(N, edge_list, h_list, J_list)
    eigen_list = H.to_spmatrix().diagonal().real

    # Initialize dictionary for single Pauli Z term with coefficient from h_list
    edge_coeff_dict = {}
    edge_coeff_dict.update({(i,): h_val for i, h_val in enumerate(h_list)})
    #Initialize dictionary for Pauli ZZ term with coefficient from from J_list
    edge_coeff_dict.update({edge: J_val for edge, J_val in zip(edge_list, J_list)})
    print('edge_coeff_dict' , edge_coeff_dict)
    #endregion


    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ITE')
    exp_poss_dict, state_ite = ITE(N, edge_coeff_dict, tau, eigen_list)
    print('exp_poss_dict', exp_poss_dict)

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ Warm start old')
    edge_params_dict, params_init, exp_poss_dict, state_all = warm_start_parameters_adaptlightcone(N, tau, 2, 0.0, edge_coeff_dict, edges_columns, eigen_list, lightcone_dict)
    print('edge_params_dict', edge_params_dict)
    print('exp_poss_dict', exp_poss_dict)
    print('overlap', np.dot(state_ite, state_all))
    # edge_params_dict, params_init, exp_poss_dict, state_old = warm_start_parameters_old(N, tau, edge_coeff_dict, edges_columns, eigen_list)
    # print('exp_poss_dict', exp_poss_dict)
    # print('overlap', np.dot(state_ite, state_old))
    #region other test
    # print('\n################################ Warm start')
    # edge_params_dict, params_init, exp_poss_dict, state_lightcone = warm_start_parameters_lightcone(N, tau, edge_coeff_dict, edges_columns, eigen_list, lightcone_dict)
    # # print(edge_params_dict)
    # print(exp_poss_dict)
    # print('overlap', np.dot(state_ite, state_lightcone))

    # print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start YZ')
    # edge_params_dict, params_init, exp_poss_dict, state_lightcone2 = warm_start_parameters_lightcone2(N, tau, 2, edge_coeff_dict, edges_columns, eigen_list, lightcone_dict)
    # print('edge_params_dict', edge_params_dict)
    # print('exp_poss_dict', exp_poss_dict)
    # print('overlap', np.dot(state_ite, state_lightcone2))

    # print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start YZ_Y')
    # edge_params_dict, params_init, exp_poss_dict, state_lightcone2 = warm_start_parameters_lightcone2(N, tau, 4, edge_coeff_dict, edges_columns, eigen_list, lightcone_dict)
    # print('edge_params_dict', edge_params_dict)
    # print('exp_poss_dict', exp_poss_dict)
    # print('overlap', np.dot(state_ite, state_lightcone2))

    # print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start YZ_Y_XY')
    # edge_params_dict, params_init, exp_poss_dict, state_lightcone2 = warm_start_parameters_lightcone2(N, tau, 6, edge_coeff_dict, edges_columns, eigen_list, lightcone_dict)
    # print('edge_params_dict', edge_params_dict)
    # print('exp_poss_dict', exp_poss_dict)
    # print('overlap', np.dot(state_ite, state_lightcone2))
    #endregion

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start all YZ_Y')
    edge_params_dict, params_init, exp_poss_dict, state_all = warm_start_parameters_adaptlightcone(N, tau, 4, 0.95, edge_coeff_dict, edges_columns, eigen_list, lightcone_dict)
    print('edge_params_dict', edge_params_dict)
    print('exp_poss_dict', exp_poss_dict)
    print('overlap', np.dot(state_ite, state_all))

    print('\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start all YZ_Y_XY')
    edge_params_dict, params_init, exp_poss_dict, state_all = warm_start_parameters_adaptlightcone(N, tau, 6, 0.95, edge_coeff_dict, edges_columns, eigen_list, lightcone_dict)
    print('edge_params_dict', edge_params_dict)
    print('exp_poss_dict', exp_poss_dict)
    print('overlap', np.dot(state_ite, state_all))
# Out:
# #############################################################################
# r: 0
# edge_coeff_dict {(0,): -0.3086, (1,): -0.696, (2,): -0.1554, (3,): -0.5975, (4,): 0.2585, (5,): -0.6503, (0, 1): -0.131, (0, 2): -0.3423, (0, 3): 0.3119, (0, 4): 0.6694, (0, 5): 0.6471, (1, 2): -0.1737, (1, 3): -0.6502, (1, 4): 0.5129, (1, 5): -0.6717, (2, 3): -0.8486, (2, 4): 0.9982, (2, 5): 0.0338, (3, 4): 0.6982, (3, 5): -0.9141, (4, 5): 0.4205}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ITE
# exp_poss_dict {-8.7043: 0.8770086943366993, -7.7197: 0.12240275843376998, -4.7528999999999995: 0.00032423617486924863, -4.1201: 9.14572989334253e-05, -3.7354999999999996: 4.237981489261159e-05, -3.675099999999999: 3.755746593820211e-05, -3.621500000000001: 3.3739598763343794e-05, -3.3716999999999997: 2.047228837415541e-05, -3.2819: 1.7106733963582533e-05, -3.0333: 1.0404851471604194e-
# overlap between ite and final optimized state:  (0.9970155407838048+0j)
#
# edge: (2, 5) ,  coeff: 0.0338
# ~~L: 0 lightcone: [(2, 5)]
# final square modulus:  -0.9996414994681461
# overlap between ite and optimized state:  (0.9963383023919437+0j)
# overlap between ite and final optimized state:  (0.9963383023919437+0j)
#
# ### column index 2 column [(1, 3), (0, 5), (2, 4)]
#
# edge: (1, 3) ,  coeff: -0.6502
# ~~L: 0 lightcone: [(1, 3)]
# final square modulus:  -0.9657322335651164
# overlap between ite and optimized state:  (0.9844473596833643+0j)
# overlap between ite and final optimized state:  (0.9844473596833643+0j)
#
# edge: (0, 5) ,  coeff: 0.6471
# ~~L: 0 lightcone: [(0, 5)]
# final square modulus:  -0.9656873258833357
# overlap between ite and optimized state:  (0.9758759590805572+0j)
# overlap between ite and final optimized state:  (0.9758759590805572+0j)
#
# edge: (2, 4) ,  coeff: 0.9982
# ~~L: 0 lightcone: [(2, 4)]
# final square modulus:  -0.9409003430371212
# overlap between ite and optimized state:  (0.9554536064687765+0j)
# overlap between ite and final optimized state:  (0.9554536064687765+0j)
#
# ### column index 3 column [(1, 5), (0, 4)]
#
# edge: (1, 5) ,  coeff: -0.6717
# ~~L: 0 lightcone: [(1, 5)]
# final square modulus:  -0.9649808307669723
# overlap between ite and optimized state:  (0.9427306044694417+0j)
# overlap between ite and final optimized state:  (0.9427306044694417+0j)
#
# edge: (0, 4) ,  coeff: 0.6694
# ~~L: 0 lightcone: [(0, 4)]
# final square modulus:  -0.895743742891157
# overlap between ite and optimized state:  (0.9458086894253515+0j)
# overlap between ite and final optimized state:  (0.9458086894253515+0j)
#
# ### column index 4 column [(3, 5), (1, 4), (0, 2)]
#
# edge: (3, 5) ,  coeff: -0.9141
# ~~L: 0 lightcone: [(3, 5)]
# final square modulus:  -0.9161557877318625
# overlap between ite and optimized state:  (0.9359198851311374+0j)
# overlap between ite and final optimized state:  (0.9359198851311374+0j)
#
# edge: (1, 4) ,  coeff: 0.5129
# ~~L: 0 lightcone: [(1, 4)]
# final square modulus:  -0.9768918133050934
# overlap between ite and optimized state:  (0.9349706233153825+0j)
# overlap between ite and final optimized state:  (0.9349706233153825+0j)
#
# edge: (0, 2) ,  coeff: -0.3423
# ~~L: 0 lightcone: [(0, 2)]
# final square modulus:  -0.9789646146236555
# overlap between ite and optimized state:  (0.9337868229930473+0j)
# overlap between ite and final optimized state:  (0.9337868229930473+0j)
#
# ### column index 5 column [(3, 4), (1, 2)]
#
# edge: (3, 4) ,  coeff: 0.6982
# ~~L: 0 lightcone: [(3, 4)]
# final square modulus:  -0.9512957263254711
# overlap between ite and optimized state:  (0.9319496911501133+0j)
# overlap between ite and final optimized state:  (0.9319496911501133+0j)
#
# edge: (1, 2) ,  coeff: -0.1737
# ~~L: 0 lightcone: [(1, 2)]
# final square modulus:  -0.9939635815991978
# overlap between ite and optimized state:  (0.9316380669333462+0j)
# overlap between ite and final optimized state:  (0.9316380669333462+0j)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start all YZ_Y
#
# ### column index 0 column [(0, 1), (2, 3), (4, 5)]
#
# edge:  (0, 1) ,  coeff:  -0.131 ,     final square modulus:  -0.999999913170239
# overlap between ite and optimized state:  (0.9999999565851185+0j)
#
# edge:  (2, 3) ,  coeff:  -0.8486 ,     final square modulus:  -0.9999996030795363
# overlap between ite and optimized state:  (0.9999997581248757+0j)
#
# edge:  (4, 5) ,  coeff:  0.4205 ,     final square modulus:  -0.9999999949659086
# overlap between ite and optimized state:  (0.999999755607831+0j)
#
# ### column index 1 column [(0, 3), (2, 5)]
#
# edge: (0, 3) ,  coeff: 0.3119
# ~~L: 0 lightcone: [(0, 3)]
# final square modulus:  -0.9896919545268661
# overlap between ite and optimized state:  (0.9947845315897599+0j)
# overlap between ite and final optimized state:  (0.9947845315897599+0j)
#
# edge: (2, 5) ,  coeff: 0.0338
# ~~L: 0 lightcone: [(2, 5)]
# final square modulus:  -0.9997655643149375
# overlap between ite and optimized state:  (0.9929007898406621+0j)
# overlap between ite and final optimized state:  (0.9929007898406621+0j)
#
# ### column index 2 column [(1, 3), (0, 5), (2, 4)]
#
# edge: (1, 3) ,  coeff: -0.6502
# ~~L: 0 lightcone: [(1, 3)]
# final square modulus:  -0.978731519465867
# overlap between ite and optimized state:  (0.9941242611649708+0j)
# overlap between ite and final optimized state:  (0.9941242611649708+0j)
#
# edge: (0, 5) ,  coeff: 0.6471
# ~~L: 0 lightcone: [(0, 5)]
# final square modulus:  -0.9848596811215576
# overlap between ite and optimized state:  (0.9870718322543917+0j)
# overlap between ite and final optimized state:  (0.9870718322543917+0j)
#
# edge: (2, 4) ,  coeff: 0.9982
# ~~L: 0 lightcone: [(2, 4)]
# final square modulus:  -0.9684798539662093
# overlap between ite and optimized state:  (0.9752874583442114+0j)
# overlap between ite and final optimized state:  (0.9752874583442114+0j)
#
# ### column index 3 column [(1, 5), (0, 4)]
#
# edge: (1, 5) ,  coeff: -0.6717
# ~~L: 0 lightcone: [(1, 5)]
# final square modulus:  -0.9713729540358634
# overlap between ite and optimized state:  (0.9638605341879373+0j)
# overlap between ite and final optimized state:  (0.9638605341879373+0j)
#
# edge: (0, 4) ,  coeff: 0.6694
# ~~L: 0 lightcone: [(0, 4)]
# final square modulus:  -0.9089560501079853
# overlap between ite and optimized state:  (0.9645812697711755+0j)
# ~~L: 1 lightcone: [(0, 5), (2, 4), (0, 4)]
# final square modulus:  -0.9629047495663751
# overlap between ite and optimized state:  (0.9481704755708952+0j)
# overlap between ite and final optimized state:  (0.9481704755708952+0j)
#
# ### column index 4 column [(3, 5), (1, 4), (0, 2)]
#
# edge: (3, 5) ,  coeff: -0.9141
# ~~L: 0 lightcone: [(3, 5)]
# final square modulus:  -0.9458342813270992
# overlap between ite and optimized state:  (0.9539140885763255+0j)
# ~~L: 1 lightcone: [(1, 5), (3, 5)]
# final square modulus:  -0.9489975617006207
# overlap between ite and optimized state:  (0.9554325896653812+0j)
# ~~L: 2 lightcone: [(1, 5), (1, 3), (0, 5), (3, 5)]
# final square modulus:  -0.9731540460776243
# overlap between ite and optimized state:  (0.9702990125722697+0j)
# overlap between ite and final optimized state:  (0.9702990125722697+0j)
#
# edge: (1, 4) ,  coeff: 0.5129
# ~~L: 0 lightcone: [(1, 4)]
# final square modulus:  -0.9891770022726447
# overlap between ite and optimized state:  (0.971685710660765+0j)
# overlap between ite and final optimized state:  (0.971685710660765+0j)
#
# edge: (0, 2) ,  coeff: -0.3423
# ~~L: 0 lightcone: [(0, 2)]
# final square modulus:  -0.9956938515602675
# overlap between ite and optimized state:  (0.9719450633660082+0j)
# overlap between ite and final optimized state:  (0.9719450633660082+0j)
#
# ### column index 5 column [(3, 4), (1, 2)]
#
# edge: (3, 4) ,  coeff: 0.6982
# ~~L: 0 lightcone: [(3, 4)]
# final square modulus:  -0.9870366335858857
# overlap between ite and optimized state:  (0.970806714661779+0j)
# overlap between ite and final optimized state:  (0.970806714661779+0j)
#
# edge: (1, 2) ,  coeff: -0.1737
# ~~L: 0 lightcone: [(1, 2)]
# final square modulus:  -0.9984938121600411
# overlap between ite and optimized state:  (0.9706249195619866+0j)
# overlap between ite and final optimized state:  (0.9706249195619866+0j)
# edge_params_dict {(0,): -0.5813773261110371, (1,): -1.0835172565134252, (2,): -0.30591383890075297, (3,): -0.9829250537267846, (4,): 0.4953973712985209, (5,): -1.0389604880740952, (0, 1): array([-0.05427743, -0.10111999, -0.03540709, -0.0921747 ]), (2, 3): array([-0.18626701, -0.51635873, -0.21266158, -0.472488  ]), (4, 5): array([ 0.13469449,  0.28425764, -0.11963632,  0.27062836]), (0, 3): array([0.03462715, 0.44420408, 0.05800746, 0.08536081]), (2, 5): array([0.0099931 , 0.0095396 , 0.00873892, 0.00884721]), (1, 3): array([-0.23741274, -0.93740998,  0.08707113,  0.63404963]), (0, 5): array([-0.8779232 ,  1.63004418,  0.29045023,  1.07340444]), (2, 4): array([ 0.84935396,  0.30650523, -0.33425676,  0.1105235 ]), (1, 5): array([-0.70685556,  0.14960299,  0.37203434, -0.21633046]), (0, 4): array([ 0.35757983,  1.09268578,  0.26896587, -1.54767441]), (3, 5): array([-0.79285262,  0.06279862,  0.07672917, -0.06847457]), (1, 4): array([ 0.23231513,  0.18375796, -0.09504287,  0.19173172]), (0, 2): array([-0.00489692, -0.39425328,  0.01080708, -0.13444174]), (3, 4): array([ 0.19502235,  0.09041801, -0.13437904,  0.0850227 ]), (1, 2): array([-0.0033722 , -0.07942348, -0.00059978,  0.08307248])}
# ~~L: 0 lightcone: [(0, 3)]
# final square modulus:  -0.9892240268373818
# overlap between ite and optimized state:  (0.9946165169163251+0j)
# overlap between ite and final optimized state:  (0.9946165169163251+0j)
#
# edge: (2, 5) ,  coeff: 0.0338
# ~~L: 0 lightcone: [(2, 5)]
# final square modulus:  -0.9997690708291961
# overlap between ite and optimized state:  (0.9927349388624276+0j)
# overlap between ite and final optimized state:  (0.9927349388624276+0j)
#
# ### column index 2 column [(1, 3), (0, 5), (2, 4)]
#
# edge: (1, 3) ,  coeff: -0.6502
# ~~L: 0 lightcone: [(1, 3)]
# final square modulus:  -0.9782811937710492
# overlap between ite and optimized state:  (0.9935609386417428+0j)
# overlap between ite and final optimized state:  (0.9935609386417428+0j)
#
# edge: (0, 5) ,  coeff: 0.6471
# ~~L: 0 lightcone: [(0, 5)]
# final square modulus:  -0.9808253060079125
# overlap between ite and optimized state:  (0.9864050992654035+0j)
# overlap between ite and final optimized state:  (0.9864050992654035+0j)
#
# edge: (2, 4) ,  coeff: 0.9982
# ~~L: 0 lightcone: [(2, 4)]
# final square modulus:  -0.964121624866614
# overlap between ite and optimized state:  (0.9744243453348868+0j)
# overlap between ite and final optimized state:  (0.9744243453348868+0j)
#
# ### column index 3 column [(1, 5), (0, 4)]
#
# edge: (1, 5) ,  coeff: -0.6717
# ~~L: 0 lightcone: [(1, 5)]
# final square modulus:  -0.9743258845099337
# overlap between ite and optimized state:  (0.96343098790792+0j)
# overlap between ite and final optimized state:  (0.96343098790792+0j)
#
# edge: (0, 4) ,  coeff: 0.6694
# ~~L: 0 lightcone: [(0, 4)]
# final square modulus:  -0.9114041876600981
# overlap between ite and optimized state:  (0.9639539316226311+0j)
# ~~L: 1 lightcone: [(0, 5), (2, 4), (0, 4)]
# final square modulus:  -0.9724327491922768
# overlap between ite and optimized state:  (0.9392762157918157+0j)
# overlap between ite and final optimized state:  (0.9392762157918157+0j)
#
# ### column index 4 column [(3, 5), (1, 4), (0, 2)]
#
# edge: (3, 5) ,  coeff: -0.9141
# ~~L: 0 lightcone: [(3, 5)]
# final square modulus:  -0.9309287490116224
# overlap between ite and optimized state:  (0.9476226627735265+0j)
# ~~L: 1 lightcone: [(1, 5), (3, 5)]
# final square modulus:  -0.937054627617037
# overlap between ite and optimized state:  (0.9482440975057618+0j)
# ~~L: 2 lightcone: [(1, 5), (1, 3), (0, 5), (3, 5)]
# final square modulus:  -0.9660679343757549
# overlap between ite and optimized state:  (0.9737518526497575+0j)
# overlap between ite and final optimized state:  (0.9737518526497575+0j)
#
# edge: (1, 4) ,  coeff: 0.5129
# ~~L: 0 lightcone: [(1, 4)]
# final square modulus:  -0.9897375525152147
# overlap between ite and optimized state:  (0.9735870882434345+0j)
# overlap between ite and final optimized state:  (0.9735870882434345+0j)
#
# edge: (0, 2) ,  coeff: -0.3423
# ~~L: 0 lightcone: [(0, 2)]
# final square modulus:  -0.9931566252684632
# overlap between ite and optimized state:  (0.9739565979815217+0j)
# overlap between ite and final optimized state:  (0.9739565979815217+0j)
# final square modulus:  -0.9895075814185903
# overlap between ite and optimized state:  (0.9835365745373783+0j)
# overlap between ite and final optimized state:  (0.9835365745373783+0j)
#
# edge: (2, 5) ,  coeff: -0.2987
# ~~L: 0 lightcone: [(2, 5)]
# final square modulus:  -0.9771445437078017
# overlap between ite and optimized state:  (0.9776315079103824+0j)
# overlap between ite and final optimized state:  (0.9776315079103824+0j)
#
# ### column index 2 column [(1, 3), (0, 5), (2, 4)]
#
# edge: (1, 3) ,  coeff: 0.4045
# ~~L: 0 lightcone: [(1, 3)]
# final square modulus:  -0.968679355371521
# overlap between ite and optimized state:  (0.9539279447004011+0j)
# overlap between ite and final optimized state:  (0.9539279447004011+0j)
#
# edge: (0, 5) ,  coeff: 0.3924
# ~~L: 0 lightcone: [(0, 5)]
# final square modulus:  -0.9488531344678753
# overlap between ite and optimized state:  (0.9365638589149505+0j)
# overlap between ite and final optimized state:  (0.9365638589149505+0j)
#
# edge: (2, 4) ,  coeff: -0.4752
# ~~L: 0 lightcone: [(2, 4)]
# final square modulus:  -0.9811209068256785
# overlap between ite and optimized state:  (0.9266391559835626+0j)
# overlap between ite and final optimized state:  (0.9266391559835626+0j)
#
# ### column index 3 column [(1, 5), (0, 4)]
#
# edge: (1, 5) ,  coeff: 0.1804
# ~~L: 0 lightcone: [(1, 5)]
# final square modulus:  -0.9850478394144812
# overlap between ite and optimized state:  (0.9173267755019576+0j)
# overlap between ite and final optimized state:  (0.9173267755019576+0j)
#
# edge: (0, 4) ,  coeff: -0.8734
# ~~L: 0 lightcone: [(0, 4)]
# final square modulus:  -0.875178617852771
# overlap between ite and optimized state:  (0.8954326387957731+0j)
# overlap between ite and final optimized state:  (0.8954326387957731+0j)
#
# ### column index 4 column [(3, 5), (1, 4), (0, 2)]
#
# edge: (3, 5) ,  coeff: 0.5184
# ~~L: 0 lightcone: [(3, 5)]
# final square modulus:  -0.8597372562996015
# overlap between ite and optimized state:  (0.9071405455368668+0j)
# overlap between ite and final optimized state:  (0.9071405455368668+0j)
#
# edge: (1, 4) ,  coeff: -0.1273
# ~~L: 0 lightcone: [(1, 4)]
# final square modulus:  -0.9918177171741394
# overlap between ite and optimized state:  (0.9046836337231815+0j)
# overlap between ite and final optimized state:  (0.9046836337231815+0j)
#
# edge: (0, 2) ,  coeff: -0.0697
# ~~L: 0 lightcone: [(0, 2)]
# final square modulus:  -0.997545995085268
# overlap between ite and optimized state:  (0.9031685483424299+0j)
# overlap between ite and final optimized state:  (0.9031685483424299+0j)
#
# ### column index 5 column [(3, 4), (1, 2)]
#
# edge: (3, 4) ,  coeff: 0.5299
# ~~L: 0 lightcone: [(3, 4)]
# final square modulus:  -0.9586684291960835
# overlap between ite and optimized state:  (0.8934967053765218+0j)
# overlap between ite and final optimized state:  (0.8934967053765218+0j)
#
# edge: (1, 2) ,  coeff: -0.0169
# ~~L: 0 lightcone: [(1, 2)]
# final square modulus:  -0.9998455060943021
# overlap between ite and optimized state:  (0.8933786494553556+0j)
000001: 3.1861910249053738e-06, 2.4453: 3.5053374086001414e-06, 2.7429: 6.257636751710272e-05, 2.8203: 1.971038152817014e-05, 2.9627000000000008: 5.449801814761042e-07, 3.0321: 4.2853632237736196e-07, 3.0686999999999998: 4.952407895897785e-06, 3.3503: 1.3029183201373095e-05, 3.3934999999999995: 4.125898185741367e-06, 3.4469000000000003: 6.2004269906530605e-06, 4.455299999999999: 3.104762424810624e-06, 5.618900000000001: 1.2646993831228806e-07}
# overlap (0.8933786494553556+0j)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start all YZ_Y
#
# ### column index 0 column [(0, 1), (2, 3), (4, 5)]
#
# edge:  (0, 1) ,  coeff:  -0.9759 ,     final square modulus:  -0.9999998911356073
# overlap between ite and optimized state:  (0.9999999455678021+0j)
#
# edge:  (2, 3) ,  coeff:  0.3248 ,     final square modulus:  -0.9999998332339443
# overlap between ite and optimized state:  (0.9999998621847757+0j)
#
# edge:  (4, 5) ,  coeff:  0.8678 ,     final square modulus:  -0.9999999691169259
# overlap between ite and optimized state:  (0.9999998467432412+0j)
#
# ### column index 1 column [(0, 3), (2, 5)]
#
# edge: (0, 3) ,  coeff: 0.1948
# ~~L: 0 lightcone: [(0, 3)]
# final square modulus:  -0.9930021084554838
# overlap between ite and optimized state:  (0.9964872972410866+0j)
# overlap between ite and final optimized state:  (0.9964872972410866+0j)
#
# edge: (2, 5) ,  coeff: -0.2987
# ~~L: 0 lightcone: [(2, 5)]
# final square modulus:  -0.9802284396543667
# overlap between ite and optimized state:  (0.9887737004745154+0j)
# overlap between ite and final optimized state:  (0.9887737004745154+0j)
#
# ### column index 2 column [(1, 3), (0, 5), (2, 4)]
#
# edge: (1, 3) ,  coeff: 0.4045
# ~~L: 0 lightcone: [(1, 3)]
# final square modulus:  -0.9829539534059354
# overlap between ite and optimized state:  (0.9771850613273804+0j)
# overlap between ite and final optimized state:  (0.9771850613273804+0j)
#
# edge: (0, 5) ,  coeff: 0.3924
# ~~L: 0 lightcone: [(0, 5)]
# final square modulus:  -0.9649593270388132
# overlap between ite and optimized state:  (0.9673939985776988+0j)
# overlap between ite and final optimized state:  (0.9673939985776988+0j)
#
# edge: (2, 4) ,  coeff: -0.4752
# ~~L: 0 lightcone: [(2, 4)]
# final square modulus:  -0.9854657718679761
# overlap between ite and optimized state:  (0.9583437782474983+0j)
# overlap between ite and final optimized state:  (0.9583437782474983+0j)
#
# ### column index 3 column [(1, 5), (0, 4)]
#
# edge: (1, 5) ,  coeff: 0.1804
# ~~L: 0 lightcone: [(1, 5)]
# final square modulus:  -0.9898324560381997
# overlap between ite and optimized state:  (0.9505811140835242+0j)
# overlap between ite and final optimized state:  (0.9505811140835242+0j)
#
# edge: (0, 4) ,  coeff: -0.8734
# ~~L: 0 lightcone: [(0, 4)]
# final square modulus:  -0.9171424151766848
# overlap between ite and optimized state:  (0.9331527136388672+0j)
# ~~L: 1 lightcone: [(0, 5), (2, 4), (0, 4)]
# final square modulus:  -0.9228830464345799
# overlap between ite and optimized state:  (0.9362674789878752+0j)
# ~~L: 2 lightcone: [(0, 5), (2, 4), (0, 3), (2, 5), (0, 4)]
# final square modulus:  -0.9319101868966698
# overlap between ite and optimized state:  (0.9465048688745734+0j)
# ~~L: 3 lightcone: [(0, 5), (2, 4), (0, 3), (2, 5), (0, 1), (2, 3), (4, 5), (0, 4)]
# final square modulus:  -0.9976534416579486
# overlap between ite and optimized state:  (0.9930071623888664+0j)
# overlap between ite and final optimized state:  (0.9930071623888664+0j)
#
# ### column index 4 column [(3, 5), (1, 4), (0, 2)]
#
# edge: (3, 5) ,  coeff: 0.5184
# ~~L: 0 lightcone: [(3, 5)]
# final square modulus:  -0.9523197659968157
# overlap between ite and optimized state:  (0.9972753075519696+0j)
# overlap between ite and final optimized state:  (0.9972753075519696+0j)
#
# edge: (1, 4) ,  coeff: -0.1273
# ~~L: 0 lightcone: [(1, 4)]
# final square modulus:  -0.9996746794695535
# overlap between ite and optimized state:  (0.9969438697713703+0j)
# overlap between ite and final optimized state:  (0.9969438697713703+0j)
#
# edge: (0, 2) ,  coeff: -0.0697
# ~~L: 0 lightcone: [(0, 2)]
# final square modulus:  -0.9996940055798438
# overlap between ite and optimized state:  (0.9963724882597985+0j)
# overlap between ite and final optimized state:  (0.9963724882597985+0j)
#
# ### column index 5 column [(3, 4), (1, 2)]
#
# edge: (3, 4) ,  coeff: 0.5299
# ~~L: 0 lightcone: [(3, 4)]
# final square modulus:  -0.9916148053161218
# overlap between ite and optimized state:  (0.9923082134741908+0j)
# overlap between ite and final optimized state:  (0.9923082134741908+0j)
#
# edge: (1, 2) ,  coeff: -0.0169
# ~~L: 0 lightcone: [(1, 2)]
# final square modulus:  -0.9999784989739361
# overlap between ite and optimized state:  (0.9922169350017261+0j)
# overlap between ite and final optimized state:  (0.9922169350017261+0j)
# edge_params_dict {(0,): 0.4024724716018626, (1,): 0.5938611165369182, (2,): 1.0775847127227034, (3,): -0.35152814365876695, (4,): 0.027996342050268685, (5,): -1.2028523792233563, (0, 1): array([ 0.03739806, -0.22016673,  0.78160084,  0.85524304]), (2, 3): array([ 0.24708476,  0.12078664, -0.22061779,  0.08986159]), (4, 5): array([-0.11844344,  0.51847295, -0.1578934 ,  0.5278789 ]), (0, 3): array([ 0.17122325, -0.02870644, -0.08096829,  0.01767768]), (2, 5): array([-0.05345291, -0.08812354,  0.100037  , -0.02299238]), (1, 3): array([0.49643327, 0.06242018, 0.22074326, 0.01056674]), (0, 5): array([ 0.83057566,  0.2174466 ,  0.54203711, -0.13107659]), (2, 4): array([ 0.00065123, -0.04220211, -0.06831897,  0.14816138]), (1, 5): array([0.09167399, 0.02596872, 0.06265576, 0.00647609]), (0, 4): array([-0.91131702, -0.14415054, -0.3394587 , -0.10676407]), (3, 5): array([ 0.03822103,  0.48340375,  0.0487563 , -0.07875506]), (1, 4): array([-0.00370685, -0.00812837,  0.00253589,  0.00767604]), (0, 2): array([-0.01555846, -0.00122141,  0.01539763,  0.00116512]), (3, 4): array([ 0.06393468,  0.53401028, -0.05104462,  0.125594  ]), (1, 2): array([-0.00347731, -0.00094333,  0.003388  ,  0.00085071])}
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start all YZ_Y_XY
#
# ### column index 0 column [(0, 1), (2, 3), (4, 5)]
#
# edge:  (0, 1) ,  coeff:  -0.9759 ,     final square modulus:  -0.9999999860140847
# overlap between ite and optimized state:  (0.9999999930070423+0j)
#
# edge:  (2, 3) ,  coeff:  0.3248 ,     final square modulus:  -0.9999994853971264
# overlap between ite and optimized state:  (0.9999997357055745+0j)
#
# edge:  (4, 5) ,  coeff:  0.8678 ,     final square modulus:  -0.999999947671536
# overlap between ite and optimized state:  (0.9999997095413493+0j)
#
# ### column index 1 column [(0, 3), (2, 5)]
#
# edge: (0, 3) ,  coeff: 0.1948
# ~~L: 0 lightcone: [(0, 3)]
# final square modulus:  -0.9930125306995995
# overlap between ite and optimized state:  (0.99650721719963+0j)
# overlap between ite and final optimized state:  (0.99650721719963+0j)
#
# edge: (2, 5) ,  coeff: -0.2987
# ~~L: 0 lightcone: [(2, 5)]
# final square modulus:  -0.9801910119716559
# overlap between ite and optimized state:  (0.98859731676329+0j)
# overlap between ite and final optimized state:  (0.98859731676329+0j)
#
# ### column index 2 column [(1, 3), (0, 5), (2, 4)]
#
# edge: (1, 3) ,  coeff: 0.4045
# ~~L: 0 lightcone: [(1, 3)]
# final square modulus:  -0.9792062331655373
# overlap between ite and optimized state:  (0.9751278496010716+0j)
# overlap between ite and final optimized state:  (0.9751278496010716+0j)
#
# edge: (0, 5) ,  coeff: 0.3924
# ~~L: 0 lightcone: [(0, 5)]
# final square modulus:  -0.9649093877343349
# overlap between ite and optimized state:  (0.9667585237886207+0j)
# overlap between ite and final optimized state:  (0.9667585237886207+0j)
#
# edge: (2, 4) ,  coeff: -0.4752
# ~~L: 0 lightcone: [(2, 4)]
# final square modulus:  -0.9855274954807262
# overlap between ite and optimized state:  (0.9587990249649158+0j)
# overlap between ite and final optimized state:  (0.9587990249649158+0j)
#
# ### column index 3 column [(1, 5), (0, 4)]
#
# edge: (1, 5) ,  coeff: 0.1804
# ~~L: 0 lightcone: [(1, 5)]
# final square modulus:  -0.9895788029579916
# overlap between ite and optimized state:  (0.951445107421021+0j)
# overlap between ite and final optimized state:  (0.951445107421021+0j)
#
# edge: (0, 4) ,  coeff: -0.8734
# ~~L: 0 lightcone: [(0, 4)]
# final square modulus:  -0.9155047702495712
# overlap between ite and optimized state:  (0.934145570651161+0j)
# ~~L: 1 lightcone: [(0, 5), (2, 4), (0, 4)]
# final square modulus:  -0.9209574590503014
# overlap between ite and optimized state:  (0.940516041008405+0j)
# ~~L: 2 lightcone: [(0, 5), (2, 4), (0, 3), (2, 5), (0, 4)]
# final square modulus:  -0.9257300481637195
# overlap between ite and optimized state:  (0.9429159764916997+0j)
# ~~L: 3 lightcone: [(0, 5), (2, 4), (0, 3), (2, 5), (0, 1), (2, 3), (4, 5), (0, 4)]
# final square modulus:  -0.9977509841142659
# overlap between ite and optimized state:  (0.993934616490494+0j)
# overlap between ite and final optimized state:  (0.993934616490494+0j)
#
# ### column index 4 column [(3, 5), (1, 4), (0, 2)]
#
# edge: (3, 5) ,  coeff: 0.5184
# ~~L: 0 lightcone: [(3, 5)]
# final square modulus:  -0.9572694235004574
# overlap between ite and optimized state:  (0.9972958538061285+0j)
# overlap between ite and final optimized state:  (0.9972958538061285+0j)
#
# edge: (1, 4) ,  coeff: -0.1273
# ~~L: 0 lightcone: [(1, 4)]
# final square modulus:  -0.9997777362484791
# overlap between ite and optimized state:  (0.9971372173055202+0j)
# ...
# overlap (0.6591487634642125+0j)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start all YZ_Y
#
# ### column index 0 column [(0, 1), (2, 3), (4, 5)]
#
# edge:  (0, 1) ,  coeff:  -0.7054 ,     final square modulus:  -0.9999999589989437
# overlap between ite and optimized state:  (0.9999999794994716+0j)
#
# edge:  (2, 3) ,  coeff:  0.5658 ,     final square modulus:  -0.9999999957655445
# overlap between ite and optimized state:  (0.9999999773822442+0j)
#
# edge:  (4, 5) ,  coeff:  0.3551 ,     final square modulus:  -0.9999999045073725
# overlap between ite and optimized state:  (0.9999999296359311+0j)
#
# ### column index 1 column [(0, 3), (2, 5)]
#
# edge: (0, 3) ,  coeff: 0.0068
# ~~L: 0 lightcone: [(0, 3)]
# final square modulus:  -0.9999746750063327
# overlap between ite and optimized state:  (0.9999869292323793+0j)
# overlap between ite and final optimized state:  (0.9999869292323793+0j)
#
# edge: (2, 5) ,  coeff: 0.1532
# ~~L: 0 lightcone: [(2, 5)]
# final square modulus:  -0.9944310151700131
# overlap between ite and optimized state:  (0.9970825154948466+0j)
# overlap between ite and final optimized state:  (0.9970825154948466+0j)
#
# ### column index 2 column [(1, 3), (0, 5), (2, 4)]
#
# edge: (1, 3) ,  coeff: 0.6827
# ~~L: 0 lightcone: [(1, 3)]
# final square modulus:  -0.8150763265942922
# overlap between ite and optimized state:  (0.8943537019528403+0j)
# ~~L: 1 lightcone: [(0, 3), (1, 3)]
# final square modulus:  -0.8964587630601217
# overlap between ite and optimized state:  (0.9328353688624602+0j)
# ~~L: 2 lightcone: [(0, 3), (0, 1), (2, 3), (1, 3)]
# final square modulus:  -0.9831972513295014
# overlap between ite and optimized state:  (0.989584005708467+0j)
# overlap between ite and final optimized state:  (0.989584005708467+0j)
#
# edge: (0, 5) ,  coeff: 0.8811
# ~~L: 0 lightcone: [(0, 5)]
# final square modulus:  -0.9307823138581931
# overlap between ite and optimized state:  (0.9465493918016123+0j)
# ~~L: 1 lightcone: [(0, 3), (2, 5), (0, 5)]
# final square modulus:  -0.9438038048635304
# overlap between ite and optimized state:  (0.9551204419067435+0j)
# ~~L: 2 lightcone: [(0, 3), (2, 5), (0, 1), (2, 3), (4, 5), (0, 5)]
# final square modulus:  -0.9781842609858786
# overlap between ite and optimized state:  (0.9772176910298366+0j)
# overlap between ite and final optimized state:  (0.9772176910298366+0j)
#
# edge: (2, 4) ,  coeff: 0.5911
# ~~L: 0 lightcone: [(2, 4)]
# final square modulus:  -0.9775799952792729
# overlap between ite and optimized state:  (0.958367557554577+0j)
# overlap between ite and final optimized state:  (0.958367557554577+0j)
#
# ### column index 3 column [(1, 5), (0, 4)]
#
# edge: (1, 5) ,  coeff: 0.5465
# ~~L: 0 lightcone: [(1, 5)]
# final square modulus:  -0.9821215621439461
# overlap between ite and optimized state:  (0.9490520354758305+0j)
# overlap between ite and final optimized state:  (0.9490520354758305+0j)
#
# edge: (0, 4) ,  coeff: 0.4756
# ~~L: 0 lightcone: [(0, 4)]
# final square modulus:  -0.9695737439638877
# overlap between ite and optimized state:  (0.9243355206064198+0j)
# overlap between ite and final optimized state:  (0.9243355206064198+0j)
#
# ### column index 4 column [(3, 5), (1, 4), (0, 2)]
#
# edge: (3, 5) ,  coeff: -0.7003
# ~~L: 0 lightcone: [(3, 5)]
# final square modulus:  -0.964645688166025
# overlap between ite and optimized state:  (0.9154001072707042+0j)
# overlap between ite and final optimized state:  (0.9154001072707042+0j)
#
# edge: (1, 4) ,  coeff: -0.8025
# ~~L: 0 lightcone: [(1, 4)]
# final square modulus:  -0.6769557092713459
# overlap between ite and optimized state:  (0.9462181261446547+0j)
# ~~L: 1 lightcone: [(1, 5), (0, 4), (1, 4)]
# final square modulus:  -0.6865336306833215
# overlap between ite and optimized state:  (0.9463977800078499+0j)
# ~~L: 2 lightcone: [(1, 5), (0, 4), (1, 3), (0, 5), (2, 4), (1, 4)]
# final square modulus:  -0.8221295434330023
# overlap between ite and optimized state:  (0.7924192912091264+0j)
# ~~L: 3 lightcone: [(1, 5), (0, 4), (1, 3), (0, 5), (2, 4), (0, 3), (2, 5), (1, 4)]
# final square modulus:  -0.9016658623709121
# overlap between ite and optimized state:  (0.8003827135825909+0j)
# ~~L: 4 lightcone: [(1, 5), (0, 4), (1, 3), (0, 5), (2, 4), (0, 3), (2, 5), (0, 1), (2, 3), (4, 5), (1, 4)]
# final square modulus:  -0.9545707257624698
# overlap between ite and optimized state:  (0.7581408749484546+0j)
# overlap between ite and final optimized state:  (0.7581408749484546+0j)
#
# edge: (0, 2) ,  coeff: 0.3396
# ~~L: 0 lightcone: [(0, 2)]
# final square modulus:  -0.9268094504416846
# overlap between ite and optimized state:  (0.8148321787722643+0j)
# ~~L: 1 lightcone: [(0, 4), (0, 2)]
# final square modulus:  -0.9368736627577793
# overlap between ite and optimized state:  (0.8125895622154573+0j)
# ~~L: 2 lightcone: [(0, 4), (0, 5), (2, 4), (0, 2)]
# final square modulus:  -0.9491889006251819
# overlap between ite and optimized state:  (0.7947839733705475+0j)
# ~~L: 3 lightcone: [(0, 4), (0, 5), (2, 4), (0, 3), (2, 5), (0, 2)]
# final square modulus:  -0.9688864377265458
# overlap between ite and optimized state:  (0.7567867760613216+0j)
# overlap between ite and final optimized state:  (0.7567867760613216+0j)
#
# ### column index 5 column [(3, 4), (1, 2)]
#
# edge: (3, 4) ,  coeff: 0.757
# ~~L: 0 lightcone: [(3, 4)]
# final square modulus:  -0.8760919058199585
# overlap between ite and optimized state:  (0.8350120666858522+0j)
# ~~L: 1 lightcone: [(3, 5), (1, 4), (3, 4)]
# final square modulus:  -0.8948977395340072
# overlap between ite and optimized state:  (0.8466730042768543+0j)
# ~~L: 2 lightcone: [(3, 5), (1, 4), (1, 5), (0, 4), (3, 4)]
# final square modulus:  -0.9033451741131178
# overlap between ite and optimized state:  (0.839740013787152+0j)
# ~~L: 3 lightcone: [(3, 5), (1, 4), (1, 5), (0, 4), (1, 3), (0, 5), (2, 4), (3, 4)]
000000004: 0.00010133133501456127, 0.35070000000000007: 0.00010981170968340962, 0.42630000000000007: 0.00018349124710298159, 0.5199: 0.00044206693427436205, 0.5488999999999999: 0.0003144880325176348, 0.6873000000000002: 3.1883238823996357e-06, 0.7706999999999999: 0.00015796052864781794, 0.8277000000000003: 0.0023964300596779667, 0.8798999999999999: 0.0005980339754846618, 0.9085000000000001: 1.568622005234503e-05, 0.9171: 1.5602792729790774e-05, 0.9233: 0.00014075681714962376, 1.0026999999999997: 0.00025616282527767887, 1.1180999999999999: 0.010396383154568352, 1.2065000000000003: 0.0005486393874738404, 1.2930999999999997: 0.0003280958742396935, 1.3810999999999998: 0.00025112041974251285, 1.4653000000000003: 0.0012487779541417627, 1.4791000000000005: 0.0025787317377789073, 1.5533000000000008: 4.100330151015411e-06, 2.1458999999999997: 0.0005256001508530682, 2.4117: 2.1663977761299525e-07, 2.4273: 0.0003904297956811628, 2.7057: 0.00044334068753145437, 2.7125000000000004: 0.002638222554689359, 2.7883000000000004: 0.0006915974361673094, 3.2587: 0.00010156056893012078, 3.4682999999999997: 0.00012482838243058577, 3.6901: 0.001486851563315156, 4.318700000000001: 2.8404463954445887e-06, 4.940499999999998: 0.00026174306713423653, 5.5307: 0.0012975911201827644}
# overlap (0.8620923055666891+0j)
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~  Warm start all YZ_Y_XY
#
# ### column index 0 column [(0, 1), (2, 3), (4, 5)]
#
# edge:  (0, 1) ,  coeff:  -0.7054 ,     final square modulus:  -0.999999912886047
# overlap between ite and optimized state:  (0.9999999564430225+0j)
#
# edge:  (2, 3) ,  coeff:  0.5658 ,     final square modulus:  -0.9999995318642904
# overlap between ite and optimized state:  (0.9999997223751514+0j)
#
# edge:  (4, 5) ,  coeff:  0.3551 ,     final square modulus:  -0.999999986958382
# overlap between ite and optimized state:  (0.9999997158543447+0j)
#
# ### column index 1 column [(0, 3), (2, 5)]
#
# edge: (0, 3) ,  coeff: 0.0068
# ~~L: 0 lightcone: [(0, 3)]
# final square modulus:  -0.9999753759743834
# overlap between ite and optimized state:  (0.999987254930413+0j)
# overlap between ite and final optimized state:  (0.999987254930413+0j)
#
# edge: (2, 5) ,  coeff: 0.1532
# ~~L: 0 lightcone: [(2, 5)]
# final square modulus:  -0.9945461830045029
# overlap between ite and optimized state:  (0.9971153945677587+0j)
# overlap between ite and final optimized state:  (0.9971153945677587+0j)
#
# ### column index 2 column [(1, 3), (0, 5), (2, 4)]
#
# edge: (1, 3) ,  coeff: 0.6827
# ~~L: 0 lightcone: [(1, 3)]
# final square modulus:  -0.8089447710922716
# overlap between ite and optimized state:  (0.8905705525226728+0j)
# ~~L: 1 lightcone: [(0, 3), (1, 3)]
# final square modulus:  -0.8547997266089757
# overlap between ite and optimized state:  (0.9123924669767787+0j)
# ~~L: 2 lightcone: [(0, 3), (0, 1), (2, 3), (1, 3)]
# final square modulus:  -0.9830435540502658
# overlap between ite and optimized state:  (0.9895735838991848+0j)
# overlap between ite and final optimized state:  (0.9895735838991848+0j)
#
# edge: (0, 5) ,  coeff: 0.8811
# ~~L: 0 lightcone: [(0, 5)]
# final square modulus:  -0.9226369747737638
# overlap between ite and optimized state:  (0.9433902088765124+0j)
# ~~L: 1 lightcone: [(0, 3), (2, 5), (0, 5)]
# final square modulus:  -0.9466737978544529
# overlap between ite and optimized state:  (0.9573268894080593+0j)
# ~~L: 2 lightcone: [(0, 3), (2, 5), (0, 1), (2, 3), (4, 5), (0, 5)]
# final square modulus:  -0.9779270538829055
# overlap between ite and optimized state:  (0.9772825821359697+0j)
# overlap between ite and final optimized state:  (0.9772825821359697+0j)
#
# edge: (2, 4) ,  coeff: 0.5911
# ~~L: 0 lightcone: [(2, 4)]
# final square modulus:  -0.9769385085545853
# overlap between ite and optimized state:  (0.9606735718675625+0j)
# overlap between ite and final optimized state:  (0.9606735718675625+0j)
#
# ### column index 3 column [(1, 5), (0, 4)]
#
# edge: (1, 5) ,  coeff: 0.5465
# ~~L: 0 lightcone: [(1, 5)]
# final square modulus:  -0.9781424918636792
# overlap between ite and optimized state:  (0.9503612719842051+0j)
# overlap between ite and final optimized state:  (0.9503612719842051+0j)
#
# edge: (0, 4) ,  coeff: 0.4756
# ~~L: 0 lightcone: [(0, 4)]
# final square modulus:  -0.9659792521186145
# overlap between ite and optimized state:  (0.9291744250481438+0j)
# overlap between ite and final optimized state:  (0.9291744250481438+0j)
#
# ### column index 4 column [(3, 5), (1, 4), (0, 2)]
#
# edge: (3, 5) ,  coeff: -0.7003
# ~~L: 0 lightcone: [(3, 5)]
# final square modulus:  -0.9619967879315049
# overlap between ite and optimized state:  (0.9194428320439433+0j)
# overlap between ite and final optimized state:  (0.9194428320439433+0j)
#
# edge: (1, 4) ,  coeff: -0.8025
# ~~L: 0 lightcone: [(1, 4)]
# final square modulus:  -0.6267129212853049
# overlap between ite and optimized state:  (0.9450226317535763+0j)
# ~~L: 1 lightcone: [(1, 5), (0, 4), (1, 4)]
# final square modulus:  -0.6375503200376065
# overlap between ite and optimized state:  (0.9369201745294184+0j)
# ~~L: 2 lightcone: [(1, 5), (0, 4), (1, 3), (0, 5), (2, 4), (1, 4)]
# final square modulus:  -0.8286517203841407
# overlap between ite and optimized state:  (0.6876241823305647+0j)
# ~~L: 3 lightcone: [(1, 5), (0, 4), (1, 3), (0, 5), (2, 4), (0, 3), (2, 5), (1, 4)]
# final square modulus:  -0.9137752998194173
# overlap between ite and optimized state:  (0.756478454762881+0j)
# ~~L: 4 lightcone: [(1, 5), (0, 4), (1, 3), (0, 5), (2, 4), (0, 3), (2, 5), (0, 1), (2, 3), (4, 5), (1, 4)]
# final square modulus:  -0.9445051494928705
# overlap between ite and optimized state:  (0.7239296363536573+0j)
# overlap between ite and final optimized state:  (0.7239296363536573+0j)
#
# edge: (0, 2) ,  coeff: 0.3396
# ~~L: 0 lightcone: [(0, 2)]
# final square modulus:  -0.925001489819372
# overlap between ite and optimized state:  (0.7657158511606921+0j)
# ~~L: 1 lightcone: [(0, 4), (0, 2)]
# final square modulus:  -0.9355880652048546
# overlap between ite and optimized state:  (0.7766042378071787+0j)
# ~~L: 2 lightcone: [(0, 4), (0, 5), (2, 4), (0, 2)]
# final square modulus:  -0.9511543273715405
# overlap between ite and optimized state:  (0.7623278455442604+0j)
# overlap between ite and final optimized state:  (0.7623278455442604+0j)
#
# ### column index 5 column [(3, 4), (1, 2)]
#
# edge: (3, 4) ,  coeff: 0.757
# ~~L: 0 lightcone: [(3, 4)]
# final square modulus:  -0.8102847810124212
# overlap between ite and optimized state:  (0.7795204791278927+0j)
# ~~L: 1 lightcone: [(3, 5), (1, 4), (3, 4)]
# final square modulus:  -0.8518819406663712
# overlap between ite and optimized state:  (0.7647713288123839+0j)
# ~~L: 2 lightcone: [(3, 5), (1, 4), (1, 5), (0, 4), (3, 4)]
# final square modulus:  -0.8612716033585768
# overlap between ite and optimized state:  (0.7707102750263255+0j)
# ~~L: 3 lightcone: [(3, 5), (1, 4), (1, 5), (0, 4), (1, 3), (0, 5), (2, 4), (3, 4)]

# %%
def warm_start_parameters_lightcone2(N : int, tau:float, numpara:int, edge_coeff_dict : dict, edges_columns :list,  eigen_list:list, lightcone_dict: dict):    

    eigens_ids = np.argsort(eigen_list)[:100]  ## return the id of the lowest 100 eigenvalues    ????
    
    edge_params_dict = {} ## to save the initial parameters for each vertex or edge in l'th layer
    exp_poss_dict = {}   ## save probalities of eigenvalues using warm start circuit

    q = QuantumRegister(N, name = 'q')
    circ = QuantumCircuit(q)
    circ.clear()
    circ.h(q[::])

    # Z term
    for i in range(N):

        #para = get_initial_para_1op_Y(N, [i], edge_coeff_dict[(i,)], tau, circ, shots, approximation)[0] #use this to extimate para from min expectation value
        tauc = tau * edge_coeff_dict[(i,)] 
        para = 2*atan( -exp(-2*tauc) ) + pi/2 #use this to use analytic formula (only valid for 1 layer)
        edge_params_dict[(i,)] = para
        circ.ry(para, i)
        
    ## ZZ term 
    state = Statevector(circ)
    updated_state = state 

    #print('\nnumber of columns is:', len(edges_columns))

    for column_index, column in enumerate(edges_columns):
        # print('\n##################################################')
        print('### column index', column_index, 'column', column)

        if column_index == 0: 
            first_column_state = state
            for edge in column:
                
                if len(lightcone_dict[edge]) != 0:
                    sys.stderr.write('something is wrong with the lightcones')
                    sys.exit()

                tauc = tau * edge_coeff_dict[edge]
                para_init = [0]* numpara
                final = minimize(square_modulus_cost_light_cone,
                        para_init,
                        args = ([edge], first_column_state, tauc, first_column_state, N),
                        jac=False,
                        bounds=None,
                        method='SLSQP',
                        callback=None,
                        options={'maxiter': 1000})
                para = final.x
                print('edge: ', edge,  ',     final square modulus: ', final.fun)

                ## test old
                final2 = minimize(square_modulus_cost_light_cone,
                        [0, 0],
                        args = ([edge], first_column_state, tauc, first_column_state, N),
                        jac=False,
                        bounds=None,
                        method='SLSQP',
                        callback=None,
                        options={'maxiter': 1000})

                print('edge: ', edge,  ',  old final square modulus: ', final2.fun)

                edge_params_dict[edge] = para
            
        else:
            print('### column index', column_index, 'column', column)
            for edge in column: 
                if len(lightcone_dict[edge]) == 0:
                        sys.stderr.write('something is wrong with the lightcones')
                        sys.exit()


                updated_state = copy.deepcopy(state) 
                for old_edge in lightcone_dict[edge]:
                    updated_state = circuit_update_theta(old_edge, updated_state, edge_params_dict[old_edge], N)    
                
                # print('updated_state', updated_state)

                edge_list = lightcone_dict[edge] + [edge]
                # print('edge list', edge_list)
                
                tauc = tau * edge_coeff_dict[edge]

                para_init = [0] * ( numpara + numpara*len(lightcone_dict[edge]))
                # print('para init', para_init)

                final = minimize(square_modulus_cost_light_cone,
                        para_init,
                        args = (edge_list, state, tauc, updated_state, N),
                        jac=False,
                        bounds=None,
                        method='SLSQP',
                        callback=None,
                        options={'maxiter': 1000})

                para = final.x
                print('\nedge: ', edge,  ',     final square modulus: ', final.fun)

                ## test old
                final2 = minimize(square_modulus_cost_light_cone,
                        [0,0],
                        args = ([edge], updated_state, tauc, updated_state, N),
                        jac=False,
                        bounds=None,
                        method='SLSQP',
                        callback=None,
                        options={'maxiter': 1000})

                print('edge: ', edge,  ',  old final square modulus: ', final2.fun)

                if abs(final.fun) > 0.0:
                    para = (np.array(para)).reshape(-1, numpara)
                    for index, edge in enumerate(edge_list):
                        edge_params_dict[edge] = para[index]
                else:
                    edge_params_dict[edge] = final2.x 
                # edge_params_dict[edge] = final2.x
            

            for edge in edges_columns[column_index -1]:
                state = circuit_update_theta(edge, state, edge_params_dict[edge], N)

    for edge in edges_columns[ -1]:
        state = circuit_update_theta(edge, state, edge_params_dict[edge], N)

    #generate params_list
    values_as_arrays = [np.atleast_1d(value) for value in edge_params_dict.values()]
    # Concatenate and flatten all arrays into a single array
    flattened_array = np.concatenate(values_as_arrays)
    # Convert the flattened array to a list if needed
    params_list = flattened_array.tolist()
    # print(' params_list' , params_list )

    state = np.array(state)

    for id in eigens_ids:
        eigen = eigen_list[id]
        poss = abs(state[id])**2
        # print('eigen', eigen, 'poss', poss)
        exp_poss_dict[eigen] = poss

    return edge_params_dict, params_list, exp_poss_dict, state

# %% [markdown]
# # Test old

# %% [markdown]
# # Test new

# %% [markdown]
# ## simplified

# %%
tau = 1
eigens_ids = np.argsort(eigen_list)[:100]  ## return the id of the lowest 100 eigenvalues    ????
    
edge_params_dict = {} ## to save the initial parameters for each vertex or edge in l'th layer
exp_poss_dict = {}   ## save probalities of eigenvalues using warm start circuit

q = QuantumRegister(N, name = 'q')
circ = QuantumCircuit(q)
circ.clear()
circ.h(q[::])

## Z term 
for i in range(N):

    #para = get_initial_para_1op_Y(N, [i], edge_coeff_dict[(i,)], tau, circ, shots, approximation)[0] #use this to extimate para from min expectation value
    tauc = tau * edge_coeff_dict[(i,)] 
    para = 2*atan( -exp(-2*tauc) ) + pi/2 #use this to use analytic formula (only valid for 1 layer)
    edge_params_dict[(i,)] = para
    circ.ry(para, i)
        
## ZZ term 
state = Statevector(circ)
updated_state = state 

print('\nnumber of columns is:', len(edges_columns))

for column_index, column in enumerate(edges_columns[:2]):
    print('\n##################################################')
    print('column index', column_index, 'column', column)

    if column_index == 0: 
        first_column_state = state
        for edge in column:
            print('edge', edge)   
            if len(lightcone_dict[edge]) != 0:
                sys.stderr.write('something is wrong with the lightcones')
                sys.exit()
        
            tauc = tau * edge_coeff_dict[edge]
            para_init = [0,0]

            final = minimize(square_modulus_cost,
                                para_init,
                                args = (edge, first_column_state, tauc, N),
                                jac=False,
                                bounds=None,
                                method='L-BFGS-B',
                                callback=None,
                                options={'maxiter': 1000})

            para = final.x
            edge_params_dict[edge] = para
        
            #first_column_state = circuit_update_theta(edge, first_column_state, para, N)  #THIS LINE SHOULDN'T BE HERE BUT SOMEHOW THERE IS A TINY NUMERICAL ERROR IN THE THETAS IF I DON'T UPDATE THE CIRCUIT
            
    else:
        for ei, edge in enumerate(column): 
            print('\nedge', edge) 
            if len(lightcone_dict[edge]) == 0:
                    sys.stderr.write('something is wrong with the lightcones')
                    print('error edge', edge)
                    sys.exit()

            print('len light cone:', len(lightcone_dict[edge]), ', light cone edges:', lightcone_dict[edge])

            updated_state = copy.deepcopy(state)
            for old_edge in edges_columns[column_index -1]:
                print('old_edge', old_edge, 'param', edge_params_dict[old_edge])
                updated_state = circuit_update_theta(old_edge, updated_state, edge_params_dict[old_edge], N)    
               

            edge_list = [edge]
            if ei > 0:
                old_edge = column[ei - 1]
                print('old_edge', old_edge, 'param', edge_params_dict[old_edge])
                updated_state = circuit_update_theta(old_edge, updated_state, edge_params_dict[old_edge], N) 
                # edge_list = [old_edge] + edge_list
            print('edge list', edge_list)
            
            tauc = tau * edge_coeff_dict[edge]

            #para_init = para_init + [0,0]
            para_init = [0,0] * len(edge_list)
            print('para init', para_init)

            final = minimize(square_modulus_cost_light_cone,
                    para_init,
                    args = (edge_list, updated_state, tauc, updated_state, N),
                    jac=False,
                    bounds=None,
                    method='L-BFGS-B',
                    callback=None,
                    options={'maxiter': 1000})

            para = final.x
            print('final.x', final.x)
            print('final.fun: ', final.fun)

            para = (np.array(para)).reshape(-1, 2)
            for index, edge in enumerate(edge_list):
                edge_params_dict[edge] = para[index] 
            print('edge_params_dict', edge_params_dict)
   

        for edge in edges_columns[column_index -1]:
            state = circuit_update_theta(edge, state, edge_params_dict[edge], N)

          

for edge in edges_columns[ 1]:
    print('edge', edge, 'parameter', edge_params_dict[edge])
    state = circuit_update_theta(edge, state, edge_params_dict[edge], N)

# # print('circuit updated at the last column i.e.', len(edges_columns) - 1)
# print('updated statevector', state)

#generate params_list
values_as_arrays = [np.atleast_1d(value) for value in edge_params_dict.values()]
# Concatenate and flatten all arrays into a single array
flattened_array = np.concatenate(values_as_arrays)
# Convert the flattened array to a list if needed
params_list = flattened_array.tolist()
print(' params_list' , params_list )

state = np.array(state)

for id in eigens_ids:
    eigen = eigen_list[id]
    poss = abs(state[id])**2
    # print('eigen', eigen, 'poss', poss)
    exp_poss_dict[eigen] = poss
print('\nedge_params_dict', edge_params_dict)
print('\nfidelity: ', exp_poss_dict)

# %% [markdown]
# ## lightcone

# %%
tau = 0.5
eigens_ids = np.argsort(eigen_list)[:100]  ## return the id of the lowest 100 eigenvalues    ????
    
edge_params_dict = {} ## to save the initial parameters for each vertex or edge in l'th layer
exp_poss_dict = {}   ## save probalities of eigenvalues using warm start circuit

q = QuantumRegister(N, name = 'q')
circ = QuantumCircuit(q)
circ.clear()
circ.h(q[::])

## Z term 
for i in range(N):

    #para = get_initial_para_1op_Y(N, [i], edge_coeff_dict[(i,)], tau, circ, shots, approximation)[0] #use this to extimate para from min expectation value
    tauc = tau * edge_coeff_dict[(i,)] 
    para = 2*atan( -exp(-2*tauc) ) + pi/2 #use this to use analytic formula (only valid for 1 layer)
    edge_params_dict[(i,)] = para
    circ.ry(para, i)
        
## ZZ term 
state = Statevector(circ)
#updated_state = state 

print('\nnumber of columns is:', len(edges_columns))

for column_index, column in enumerate(edges_columns):
    print('\n##################################################')
    print('column index', column_index, 'column', column)

    if column_index == 0: 
        first_column_state = state
        for edge in column:
            print('edge', edge)   
            if len(lightcone_dict[edge]) != 0:
                sys.stderr.write('something is wrong with the lightcones')
                sys.exit()
        
            tauc = tau * edge_coeff_dict[edge]
            para_init = [0,0]

            final = minimize(square_modulus_cost,
                                para_init,
                                args = (edge, first_column_state, tauc, N),
                                jac=False,
                                bounds=None,
                                method='L-BFGS-B',
                                callback=None,
                                options={'maxiter': 1000})

            para = final.x
            edge_params_dict[edge] = para
        
            first_column_state = circuit_update_theta(edge, first_column_state, para, N)  #THIS LINE SHOULDN'T BE HERE BUT SOMEHOW THERE IS A TINY NUMERICAL ERROR IN THE THETAS IF I DON'T UPDATE THE CIRCUIT
            
    else:
        for ei, edge in enumerate(column): 
            print('edge', edge) 
            if len(lightcone_dict[edge]) == 0:
                    sys.stderr.write('something is wrong with the lightcones')
                    print('error edge', edge)
                    sys.exit()

            print('len light cone:', len(lightcone_dict[edge]), ', light cone edges:', lightcone_dict[edge])

            updated_state = copy.deepcopy(state)
            para_init = []
            edge_list = []
            for ci in range(column_index):
                for old_edge in edges_columns[ci]:
                    #print('old_edge', old_edge, 'param', edge_params_dict[old_edge])
                    edge_list.append(old_edge)
                    para_init.extend(list(edge_params_dict[old_edge]))
                    updated_state = circuit_update_theta(old_edge, updated_state, edge_params_dict[old_edge], N)    
            if ei > 0:
                for old_edge in column[:ei]:
                    print('old_edge', old_edge, 'param', edge_params_dict[old_edge])
                    edge_list.append(old_edge)
                    para_init.extend(list(edge_params_dict[old_edge]))
                    updated_state = circuit_update_theta(old_edge, updated_state, edge_params_dict[old_edge], N) 
                # edge_list = [old_edge] + edge_list

            edge_list = edge_list + [edge]
            print('edge list', edge_list)
            
            tauc = tau * edge_coeff_dict[edge]

            para_init = para_init + [0,0]
            print('para init', para_init)

            final = minimize(square_modulus_cost_light_cone,
                    para_init,
                    args = (edge_list, state, tauc, updated_state, N),
                    jac=False,
                    bounds=None,
                    method='COBYLA',
                    callback=None,
                    options={'maxiter': 1000})

            para = final.x
            print('final.x', final.x)
            print('final.fun: ', final.fun)

            para = (np.array(para)).reshape(-1, 2)
            for index, edge in enumerate(edge_list):
                edge_params_dict[edge] = para[index] 
            print('edge_params_dict', edge_params_dict)
   

        # for edge in edges_columns[column_index -1]:
        #     state = circuit_update_theta(edge, state, edge_params_dict[edge], N)

          
for ci in range(len(edges_columns)):
    for edge in edges_columns[ ci]:
        print('edge', edge, 'parameter', edge_params_dict[edge])
        state = circuit_update_theta(edge, state, edge_params_dict[edge], N)

# # print('circuit updated at the last column i.e.', len(edges_columns) - 1)
# print('updated statevector', state)

# #generate params_list
# values_as_arrays = [np.atleast_1d(value) for value in edge_params_dict.values()]
# # Concatenate and flatten all arrays into a single array
# flattened_array = np.concatenate(values_as_arrays)
# # Convert the flattened array to a list if needed
# params_list = flattened_array.tolist()
# print(' params_list' , params_list )

state = np.array(state)

for id in eigens_ids:
    eigen = eigen_list[id]
    poss = abs(state[id])**2
    # print('eigen', eigen, 'poss', poss)
    exp_poss_dict[eigen] = poss
print('\nedge_params_dict', edge_params_dict)
print('\nfidelity: ', exp_poss_dict)

# %% [markdown]
# # ITE

# %%
eigens_ids = np.argsort(eigen_list)[:100]  ## return the id of the lowest 100 eigenvalues    ????
    
edge_params_dict = {} ## to save the initial parameters for each vertex or edge in l'th layer
exp_poss_dict = {}   ## save probalities of eigenvalues using warm start circuit

q = QuantumRegister(N, name = 'q')
circ = QuantumCircuit(q)
circ.clear()
circ.h(q[::])

## Z term 
for i in range(N):

    #para = get_initial_para_1op_Y(N, [i], edge_coeff_dict[(i,)], tau, circ, shots, approximation)[0] #use this to extimate para from min expectation value
    tauc = tau * edge_coeff_dict[(i,)] 
    para = 2*atan( -exp(-2*tauc) ) + pi/2 #use this to use analytic formula (only valid for 1 layer)
    edge_params_dict[(i,)] = para
    circ.ry(para, i)
        
## ZZ term 
state = Statevector(circ)

for edge in G.edges():
    coeff = edge_coeff_dict[edge]
    print('edge', edge, 'coeff', coeff)
    tauc = tau * coeff
    state = circuit_update_zz(edge, state, tauc, N)

state = np.array(state)
for id in eigens_ids:
    eigen = eigen_list[id]
    poss = abs(state[id])**2
    # print('eigen', eigen, 'poss', poss)
    exp_poss_dict[eigen] = poss
print('\nedge_params_dict', edge_params_dict)
print('\nfidelity: ', exp_poss_dict)

# %%
def ITE(N, qi, coeff, tau, vec):
    """
    Caculating the statevector after imiginary time evolution, 
    i.e, e^{- tau * coeff * Z_i} * vec, or e^{- tau * coeff * Z_jZ_i} * vec
    
    Args:
        N: int, number of qubits
        qi: qubit index list, [i] for single-qubit term, [i,j] for two-qubit term
        coeff: float, coeffieicnt of the terms acting on qubit i or (i, j)
        tau: float, time for imaginary time evolution
        vec:numpy.array,  the statevector of current state
    Return:
        vec_tau / norm: numpy.array, normalized statevector after imiginary time evolution
    """
    
    if len(qi) == 1:  ## single Z term
        i = qi[0]
        Z_op = Pauli('I'*(N-1-i) + 'Z' + 'I'*i)
    elif len(qi) == 2: ## two body term Z_jZ_i
        i = min(qi)
        j = max(qi)
        Z_op = Pauli('I'*(N-1-j) + 'Z' + 'I'*(j-i-1) + 'Z' + 'I'*i)
        
    Z_op_diag = Z_op.to_matrix(sparse=True).diagonal().real
    vec_z = np.multiply(Z_op_diag, vec)  ## multiplying each element
    vec_tau = np.cosh(coeff * tau) * vec - np.sinh(coeff * tau) * vec_z
    
    norm = np.linalg.norm(vec_tau)
    
    return vec_tau / norm

# %%
eigens_ids = np.argsort(eigen_list)[:100]  ## return the id of the lowest 100 eigenvalues    ????
    
edge_params_dict = {} ## to save the initial parameters for each vertex or edge in l'th layer
exp_poss_dict = {}   ## save probalities of eigenvalues using warm start circuit

vec = np.ones(2**N) / np.sqrt(2**N)

## Z term 
for i in range(N):
    coeff = edge_coeff_dict[(i,)]
    vec = ITE(N, [i], coeff, tau, vec)
        

## ZZ term
for edge in G.edges():
    coeff = edge_coeff_dict[edge]
    vec = ITE(N, edge, coeff, tau, vec)

state = vec
for id in eigens_ids:
    eigen = eigen_list[id]
    poss = abs(state[id])**2
    # print('eigen', eigen, 'poss', poss)
    exp_poss_dict[eigen] = poss
print('\nedge_params_dict', edge_params_dict)
print('\nfidelity: ', exp_poss_dict)
